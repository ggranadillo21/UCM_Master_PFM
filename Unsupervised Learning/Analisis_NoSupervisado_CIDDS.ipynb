# %% [markdown]
# # Local Outlier Factor
# El algoritmo Local Outlier Factor (LOF) es un método de detección de anomalías no supervisado que calcula la desviación de densidad local de un punto de datos dado con respecto a sus vecinos. Considera como valores atípicos las muestras que tienen una densidad sustancialmente más baja que sus vecinas.

# %%
#Importamos Librerias

# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd
from mat4py import loadmat
from sklearn.datasets import make_blobs
from numpy import where

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
#style.use('ggplot') or plt.style.use('ggplot')

# Preprocesado y modelado
# ==============================================================================
from sklearn.ensemble import IsolationForest
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import OneClassSVM
from sklearn.metrics import confusion_matrix
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
#importamos dataset para el training. Usaremos una muestra de poco más de 10mil observaciones
data = pd.read_csv('muestra1.csv')
data.head(10)
# Out:
#    Unnamed: 0  Duration  Proto  SrcPt    DstPt  Packets   Bytes  Flags  Tos  \
# 0           1     0.000      6  33877    443.0        1    66.0     16    0
# 1           2     0.042      6     80  52335.0        2   413.0     26   32
# 2           3     0.215      6  51696     80.0        8  1350.0     26    0
# 3           4     0.143      6  37251    443.0        4  1810.0     24    0
# 4           5     0.000      6  35641     80.0        1    66.0     16    0
# 5           6     0.000      6  51797     80.0        1    66.0     16    0
# 6           7     0.100      6  46737    443.0       12  1623.0     26    0
# 7           8     0.019      6  45026     80.0        2   132.0     17    0
# 8           9     1.300      6  63394    443.0        4  1490.0     24    0
# 9          10     0.000     17  45532     53.0        1    73.0      0    0
#
#    class  Packets_speed    Bytes_speed  Hour  Min  Sec
# 0      0   10000.000000  660000.000000    36   30    3
# 1      0      47.619048    9833.333333    24   54    3
# 2      0      37.209302    6279.069767    28   50    0
# 3      0      27.972028   12657.342657    38   32    6
# 4      0   10000.000000  660000.000000    44   37    8
# 5      0   10000.000000  660000.000000    10   43    2
# 6      0     120.000000   16230.000000    27   31    4
# 7      0     105.263158    6947.368421    51    0    9
# 8      0       3.076923    1146.153846    47   14    4
# 9      0   10000.000000  730000.000000    30   36    3

# %%
# Seleccionamos las features que usaremos en el entrenamiento. He hecho pruebas cambiando las variables desde una hasta usarlas todas
#La mejor combinación de features para este algoritmo es la siguiente
from numpy import quantile, where, random

# model specification
from sklearn.neighbors import LocalOutlierFactor
data = pd.read_csv('muestra1.csv')
datos_X1 = pd.DataFrame(data[['SrcPt', 'Flags', 'Tos', 'Proto', 'DstPt']])
datos_y1 = pd.DataFrame(data[['class']])

model = LocalOutlierFactor(n_neighbors=2)
model.fit_predict(X=datos_X1)
lof = model.negative_outlier_factor_
cuantil_01 = quantile(lof, .22)
score = pd.DataFrame(lof)
anomalia = pd.DataFrame(datos_y1)
df_resultados = score.join(anomalia)
df_resultados = df_resultados.rename(columns={0:'score', 'class':'anomalia'})
df_resultados = df_resultados \
                .sort_values('score', ascending=True) \
                .reset_index(drop=True)

df_resultados['clasificacion'] = np.where(df_resultados.score <= cuantil_01, 1, 0)
confusion_matrix(df_resultados.anomalia, df_resultados.clasificacion)
# Out:
# array([[7217, 2032],
#        [ 962,  275]], dtype=int64)

# %% [markdown]
# Resultados no muy buenos, sobre todo para la predicción de anomalías que no llega ni al 50%

# %% [markdown]
# # K-means
# K-means es un algoritmo de clasificación no supervisada (clusterización) que agrupa objetos en k grupos basándose en sus características. El agrupamiento se realiza minimizando la suma de distancias entre cada objeto y el centroide de su grupo o cluster. Se suele usar la distancia cuadrática.

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.metrics import confusion_matrix

#Cargamos el dataset y lo asignamos a la variable data
data = pd.read_csv('muestra1.csv')
#seleccionamos las variables que usaremos en el análisis. He hecho pruebas con diferentes de set de variables y esta es la que
#genera mejores resultados predictivos para ambas clases
df = data[['Duration', 'Proto', 'SrcPt', 'DstPt']]
#Definimos el número de clusters, en este caso al ser 2 clases, necesitamos 2 clusters
km = KMeans(n_clusters=2)
#Hacemos un fit para obtener las predicciones
y_predicted = km.fit_predict(df)
#creamos un dataframe con las prediciones generadas
y_pred = pd.DataFrame(y_predicted)
#definimos la variable objetivo
y_train = data[["class"]]
#calculamos la matrix de confusión tomando como input las predicciones y los valores reales
confusion_matrix(y_train, y_pred)
# Out:
# array([[4616, 4633],
#        [ 637,  600]], dtype=int64)

# %% [markdown]
# Pésimos resultados, al probar con otros sets de variables, cuando se mejora una clase, se empeora la predicción de la otra, al final, este fue lo mejor que pude obtener con K-means, quizás para un estudio multiclase (de 3 o más clusters) podría ser más interesante.

# %% [markdown]
# # Isolation Forest
# Al igual que en Random Forest, un modelo Isolation Forest está formado por la combinación de múltiples árboles llamados isolation trees. Estos árboles se crea de forma similar a los de clasificación-regresión: las observaciones de entrenamiento se van separando de forma recursiva creando las ramas del árbol hasta que cada observación queda aislada en un nodo terminal. Sin embargo, en los isolation tree, la selección de los puntos de división se hace de forma aleatoria. Aquellas observaciones con características distintas al resto, quedarán aisladas a las pocas divisiones, por lo que el número de nodos necesarios para llegar a estas observación desde el inicio del árbol (profundidad) es menor que para el resto.

# %%
#Cargamos el dataset y lo asignamos a la variable df
df = pd.read_csv('muestra1.csv')
#seleccionamos las columnas con las variables más predictoras. He hecho pruebas con distintos sets de variables, éste es el que 
#ofrece mejores resultados
datos_X1 = pd.DataFrame(df[['Proto', 'SrcPt', 'DstPt', 'Flags', 'Tos']])
#definición de la variable objetivo
datos_y1 = pd.DataFrame(df[['class']])

#Tuneado de parámetros del algoritmo
modelo_isof1 = IsolationForest(
                n_estimators  = 1000, #número de árboles que forman el modelo
                max_samples   ='auto', #número de observaciones empleadas para entrenar cada árbol
                contamination = 0.118, #proporción de anomalías esperadas en los datos de entrenamiento
                n_jobs        = -1,
                random_state  = 123, #semilla para garantizar la reproducibilidad de los resultados
            )
#Se procede a entrenar un modelo asumiendo que hay un 11,8% de observaciones anómalas en el conjunto de entrenamiento
modelo_isof1.fit(X=datos_X1)
#generamos las predicciones y la asigamos a una variable
clasificacion_predicha1 = modelo_isof1.predict(X=datos_X1)
# Predicción valor anomalía
score_anomalia1 = modelo_isof1.score_samples(X=datos_X1)
#Calculamos el quantile o threshold de las anomalias a partir de las cuales, una observación se considerará anómala
cuantil_01 = np.quantile(score_anomalia1, q=0.118)
#Calculamos el score de anomalías para cada observación
score1 = pd.DataFrame(score_anomalia1)
#Creamos un dataset con los valores reales del dataset
anomalia1 = pd.DataFrame(datos_y1)
#Unimos los valores reales y las predicciones
df_resultados1 = score1.join(anomalia1)
#Renombramos las columnos por Score y Anomalia
df_resultados1 = df_resultados1.rename(columns={0:'score', 'class':'anomalia'})
#ordenamos en forma ascendiente los scores de anomalías
df_resultados1 = df_resultados1 \
                .sort_values('score', ascending=True) \
                .reset_index(drop=True)
#Convertimos el score anomalías en 1 (si es mayor que el quantil) o 0 (si es menor)
df_resultados1['clasificacion'] = np.where(df_resultados1.index <= 1237, 1, 0)
# Matriz de confusión de la clasificación final
pd.crosstab(
    df_resultados1.anomalia,
    df_resultados1.clasificacion
)
# Out:
# clasificacion     0     1
# anomalia
# 0              8131  1118
# 1              1117   120

# %% [markdown]
# Resultados también muy malos, con pocos aciertos en la clase de anomalías.

# %% [markdown]
# # One-Class SVM
# El algoritmo es una extensión natural del SVC (support vector classifier) para el caso de información no etiquetada. One-Class SVM busca  capturar  una  región  en  donde  se  concentra  la  densidad  de  probabilidad,  es  decir encontrar  una  función  que  separe  la  gran  mayoría  de  los  datos  hacia  un  lado (suministros  normales),  identificando  de  esta  forma  las  “novedades”  (posibles suministros  con  irregularidades)  como  los  datos  que  quedan  del  otro  lado  de  la superficie  de  decisión.

# %%
#Cargamos el dataset
data = pd.read_csv('muestra1.csv')
#seleccionamos las variables más predictoras
df = data[['Duration', 'SrcPt', 'Packets', 'Tos', 'Packets_speed', 'Bytes_speed', 'DstPt']]
#Definimos los parámetros del modelo
model = OneClassSVM(kernel = 'rbf', gamma = 0.25, nu = 0.5).fit(df)
#Realizamos las predicciones
y_pred = model.predict(df)
#creamos un dataframe con las predicciones generadas
y_pred = pd.DataFrame(y_pred)
#Si la predicción es -1 la pasamos a 1 (caso anomalía), sino la pasamos a 0 (caso normal) 
y_pred.loc[y_pred[0]==1]=0
y_pred.loc[y_pred[0]==-1]=1
#definimos la variable objetivo
y_train = data[["class"]]
#Creamos matriz de confusión
confusion_matrix(y_train, y_pred)
# Out:
# array([[4272, 4977],
#        [ 885,  352]], dtype=int64)

# %% [markdown]
# Resultados no muy buenos, pero se logra un aumento en la detección de anomalías

# %% [markdown]
# # Autoencoder
# Es un tipo de arquitectura de redes neuronales que pertenece al grupo de métodos de aprendizaje no supervisados. Esta arquitectura extrae las características más importantes del input eliminando el resto de poca relevancia. Esto permite que los autoencoders aprendan una representación de la información reducida siendo un perfecto método para comprimir información.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from numpy.random import seed
seed(1)

# %%
#Cargamos dataset y seleccionamos las variables más predictoras
df = pd.read_csv('train_CIDDS.csv')
datos_X = pd.DataFrame(df[['Duration', 'Proto', 'DstPt', 'Bytes', 'Flags', 'Tos', 'Packets_speed', 'Bytes_speed']])
datos_y = pd.DataFrame(df[['class']])
x_train = datos_X
y_train = datos_y

#cargamos el dataset de test
df1 = pd.read_csv("muestra1.csv")
x_test = pd.DataFrame(df1[['Duration', 'Proto', 'DstPt', 'Bytes', 'Flags', 'Tos', 'Packets_speed', 'Bytes_speed']])
y_test = pd.DataFrame(df1[['class']])

# estandarizamos y hacemos fit
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x_train_scaled = min_max_scaler.fit_transform(x_train.copy())
x_test_scaled = min_max_scaler.transform(x_test.copy())

# creamos modelo en tensorflow
class AutoEncoder(Model):
  """
  Parameters
  ----------
  output_units: int
    Number of output units
  
  code_size: int
    Number of units in bottle neck
  """
#definimos el codificador con 512, 256 y 128 neuronas en cada capa
  def __init__(self, output_units, code_size=10):
    super().__init__()
    self.encoder = Sequential([
      Dense(512, activation='relu'),
      Dropout(0.1), 
      Dense(256, activation='relu'),
      Dropout(0.1),
      Dense(128, activation='relu'),
      Dropout(0.1),
      Dense(code_size, activation='relu')
    ])
    #definimos el decodificador con 128, 256 y 512 neuronas en cada capa
    self.decoder = Sequential([
      Dense(128, activation='relu'),
      Dropout(0.1),
      Dense(256, activation='relu'),
      Dropout(0.1),
      Dense(512, activation='relu'),
      Dropout(0.1),
      Dense(output_units, activation='sigmoid')
    ])
  
  def call(self, inputs):
    encoded = self.encoder(inputs)
    decoded = self.decoder(encoded)
    return decoded
#creamos el modelo con el algoritmo autoencoder  
model = AutoEncoder(output_units=x_train_scaled.shape[1])
# configuramos el modelo 
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
#hacemos un fit del modelo con los parámetros tuneados (se han probado epochs y batch_size con diferentes valores)
history = model.fit(
    x_train_scaled,
    x_train_scaled,
    epochs=500,
    batch_size=128,
    validation_data=(x_test_scaled, x_test_scaled)
)

#funciones necesarias
def find_threshold(model, x_train_scaled):
  reconstructions = model.predict(x_train_scaled)
  # provides losses of individual instances
  reconstruction_errors = tf.keras.losses.msle(reconstructions, x_train_scaled)
  # threshold for anomaly scores
  threshold = np.mean(reconstruction_errors.numpy()) \
      + np.std(reconstruction_errors.numpy())
  return threshold

def get_predictions(model, x_test_scaled, threshold):
  predictions = model.predict(x_test_scaled)
  # provides losses of individual instances
  errors = tf.keras.losses.msle(predictions, x_test_scaled)
  # 1 = anomaly, 0 = normal
  anomaly_mask = pd.Series(errors) > threshold
  preds = anomaly_mask.map(lambda x: 1 if x == True else 0)
  return preds
#obtenemos el valor del threshold
threshold = find_threshold(model, x_train_scaled)
print(f"Threshold: {threshold}")

#generamos las predicciones
predictions = get_predictions(model, x_test_scaled, threshold)
predictions = pd.DataFrame(predictions) #convertimos en dataframe
predictions = predictions.rename(columns={0:'class_pred'})#renombramos la columna 0 por class_pred
y_test = y_test.rename(columns={1:'class'}) #renombramos la columna 1 por class
y_test["class"] = y_test["class"].astype(str).astype(int)
#calculamos accuracy del modelo
accuracy_score(predictions, y_test)
#calculamos la matriz de confusión
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# Epoch 1/500
# 125/125 [==============================] - 3s 18ms/step - loss: 0.2641 - accuracy: 0.7676 - val_loss: 0.2020 - val_accuracy: 0.9935
# Epoch 2/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2019 - accuracy: 0.9526 - val_loss: 0.1985 - val_accuracy: 0.9847
# Epoch 3/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1997 - accuracy: 0.9622 - val_loss: 0.1975 - val_accuracy: 0.9817
# Epoch 4/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1985 - accuracy: 0.9654 - val_loss: 0.1961 - val_accuracy: 0.9810
# Epoch 5/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1975 - accuracy: 0.9678 - val_loss: 0.1957 - val_accuracy: 0.9767
# Epoch 6/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1970 - accuracy: 0.9696 - val_loss: 0.1954 - val_accuracy: 0.9784
# Epoch 7/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1967 - accuracy: 0.9707 - val_loss: 0.1953 - val_accuracy: 0.9581
# Epoch 8/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1965 - accuracy: 0.9682 - val_loss: 0.1952 - val_accuracy: 0.9873
# Epoch 9/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1962 - accuracy: 0.9729 - val_loss: 0.1950 - val_accuracy: 0.9832
# Epoch 10/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1961 - accuracy: 0.9726 - val_loss: 0.1950 - val_accuracy: 0.9822
# Epoch 11/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1960 - accuracy: 0.9714 - val_loss: 0.1949 - val_accuracy: 0.9764
# Epoch 12/500
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1961 - accuracy: 0.9728 - val_loss: 0.1948 - val_accuracy: 0.9782
# Epoch 13/500
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1959 - accuracy: 0.9711 - val_loss: 0.1950 - val_accuracy: 0.9746
# Epoch 14/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1958 - accuracy: 0.9731 - val_loss: 0.1949 - val_accuracy: 0.9824
# Epoch 15/500
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1957 - accuracy: 0.9729 - val_loss: 0.1947 - val_accuracy: 0.9781
# Epoch 16/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1957 - accuracy: 0.9764 - val_loss: 0.1948 - val_accuracy: 0.9867
# Epoch 17/500
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1956 - accuracy: 0.9739 - val_loss: 0.1947 - val_accuracy: 0.9830
# Epoch 18/500
# 125/125 [==============================] - 3s 28ms/step - loss: 0.1955 - accuracy: 0.9744 - val_loss: 0.1946 - val_accuracy: 0.9776
# Epoch 19/500
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1954 - accuracy: 0.9747 - val_loss: 0.1946 - val_accuracy: 0.9799
# Epoch 20/500
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1954 - accuracy: 0.9751 - val_loss: 0.1947 - val_accuracy: 0.9786
# Epoch 21/500
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1953 - accuracy: 0.9740 - val_loss: 0.1947 - val_accuracy: 0.9685
# Epoch 22/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1954 - accuracy: 0.9742 - val_loss: 0.1947 - val_accuracy: 0.9543
# Epoch 23/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1954 - accuracy: 0.9734 - val_loss: 0.1945 - val_accuracy: 0.9763
# Epoch 24/500
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1953 - accuracy: 0.9754 - val_loss: 0.1946 - val_accuracy: 0.9810
# Epoch 25/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1952 - accuracy: 0.9749 - val_loss: 0.1945 - val_accuracy: 0.9723
# Epoch 26/500
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1952 - accuracy: 0.9764 - val_loss: 0.1945 - val_accuracy: 0.9694
# Epoch 27/500
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1952 - accuracy: 0.9748 - val_loss: 0.1945 - val_accuracy: 0.9728
# Epoch 28/500
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1951 - accuracy: 0.9758 - val_loss: 0.1944 - val_accuracy: 0.9676
# Epoch 29/500
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1951 - accuracy: 0.9772 - val_loss: 0.1945 - val_accuracy: 0.9645
# Epoch 30/500
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1952 - accuracy: 0.9756 - val_loss: 0.1944 - val_accuracy: 0.9846
# Epoch 31/500
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1951 - accuracy: 0.9775 - val_loss: 0.1945 - val_accuracy: 0.9805
# Epoch 32/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1952 - accuracy: 0.9775 - val_loss: 0.1946 - val_accuracy: 0.9742
# Epoch 33/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9787 - val_loss: 0.1943 - val_accuracy: 0.9742
# Epoch 34/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1951 - accuracy: 0.9761 - val_loss: 0.1945 - val_accuracy: 0.9640
# Epoch 35/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1951 - accuracy: 0.9771 - val_loss: 0.1947 - val_accuracy: 0.9813
# Epoch 36/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9794 - val_loss: 0.1944 - val_accuracy: 0.9802
# Epoch 37/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1950 - accuracy: 0.9793 - val_loss: 0.1945 - val_accuracy: 0.9848
# Epoch 38/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1950 - accuracy: 0.9799 - val_loss: 0.1945 - val_accuracy: 0.9820
# Epoch 39/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9794 - val_loss: 0.1943 - val_accuracy: 0.9764
# Epoch 40/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9804 - val_loss: 0.1944 - val_accuracy: 0.9660
# Epoch 41/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9773 - val_loss: 0.1950 - val_accuracy: 0.9824
# Epoch 42/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9781 - val_loss: 0.1943 - val_accuracy: 0.9874
# Epoch 43/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9782 - val_loss: 0.1944 - val_accuracy: 0.9588
# Epoch 44/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9779 - val_loss: 0.1944 - val_accuracy: 0.9693
# Epoch 45/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9779 - val_loss: 0.1945 - val_accuracy: 0.9695
# Epoch 46/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9794 - val_loss: 0.1945 - val_accuracy: 0.9868
# Epoch 47/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9806 - val_loss: 0.1944 - val_accuracy: 0.9703
# Epoch 48/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1951 - accuracy: 0.9788 - val_loss: 0.1948 - val_accuracy: 0.9600
# Epoch 49/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1952 - accuracy: 0.9767 - val_loss: 0.1946 - val_accuracy: 0.9802
# Epoch 50/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9779 - val_loss: 0.1945 - val_accuracy: 0.9797
# Epoch 51/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9797 - val_loss: 0.1944 - val_accuracy: 0.9889
# Epoch 52/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1951 - accuracy: 0.9753 - val_loss: 0.1945 - val_accuracy: 0.9744
# Epoch 53/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9763 - val_loss: 0.1945 - val_accuracy: 0.9854
# Epoch 54/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9794 - val_loss: 0.1944 - val_accuracy: 0.9875
# Epoch 55/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9792 - val_loss: 0.1943 - val_accuracy: 0.9864
# Epoch 56/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9813 - val_loss: 0.1944 - val_accuracy: 0.9844
# Epoch 57/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9786 - val_loss: 0.1944 - val_accuracy: 0.9887
# Epoch 58/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1945 - val_accuracy: 0.9895
# Epoch 59/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9794 - val_loss: 0.1946 - val_accuracy: 0.9855
# Epoch 60/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9794 - val_loss: 0.1947 - val_accuracy: 0.9831
# Epoch 61/500
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1949 - accuracy: 0.9803 - val_loss: 0.1945 - val_accuracy: 0.9805
# Epoch 62/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9797 - val_loss: 0.1944 - val_accuracy: 0.9732
# Epoch 63/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1943 - val_accuracy: 0.9866
# Epoch 64/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9822 - val_loss: 0.1944 - val_accuracy: 0.9868
# Epoch 65/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9803 - val_loss: 0.1950 - val_accuracy: 0.9573
# Epoch 66/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9774 - val_loss: 0.1944 - val_accuracy: 0.9835
# Epoch 67/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9829 - val_loss: 0.1943 - val_accuracy: 0.9839
# Epoch 68/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9832 - val_loss: 0.1944 - val_accuracy: 0.9791
# Epoch 69/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9797 - val_loss: 0.1946 - val_accuracy: 0.9665
# Epoch 70/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9802 - val_loss: 0.1945 - val_accuracy: 0.9847
# Epoch 71/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9807 - val_loss: 0.1946 - val_accuracy: 0.9872
# Epoch 72/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1946 - val_accuracy: 0.9846
# Epoch 73/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9810 - val_loss: 0.1945 - val_accuracy: 0.9818
# Epoch 74/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9821 - val_loss: 0.1943 - val_accuracy: 0.9869
# Epoch 75/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9821 - val_loss: 0.1945 - val_accuracy: 0.9859
# Epoch 76/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9811 - val_loss: 0.1944 - val_accuracy: 0.9849
# Epoch 77/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9812 - val_loss: 0.1945 - val_accuracy: 0.9842
# Epoch 78/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1953 - accuracy: 0.9766 - val_loss: 0.1943 - val_accuracy: 0.9799
# Epoch 79/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9779 - val_loss: 0.1948 - val_accuracy: 0.9847
# Epoch 80/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9794 - val_loss: 0.1946 - val_accuracy: 0.9795
# Epoch 81/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9782 - val_loss: 0.1947 - val_accuracy: 0.9797
# Epoch 82/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9825 - val_loss: 0.1949 - val_accuracy: 0.9806
# Epoch 83/500
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1948 - accuracy: 0.9816 - val_loss: 0.1948 - val_accuracy: 0.9761
# Epoch 84/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1948 - accuracy: 0.9824 - val_loss: 0.1949 - val_accuracy: 0.9771
# Epoch 85/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9809 - val_loss: 0.1944 - val_accuracy: 0.9665
# Epoch 86/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9802 - val_loss: 0.1944 - val_accuracy: 0.9688
# Epoch 87/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9809 - val_loss: 0.1946 - val_accuracy: 0.9825
# Epoch 88/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9809 - val_loss: 0.1947 - val_accuracy: 0.9793
# Epoch 89/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1947 - val_accuracy: 0.9804
# Epoch 90/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9824 - val_loss: 0.1948 - val_accuracy: 0.9712
# Epoch 91/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9788 - val_loss: 0.1947 - val_accuracy: 0.9785
# Epoch 92/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9783 - val_loss: 0.1947 - val_accuracy: 0.9807
# Epoch 93/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9805 - val_loss: 0.1946 - val_accuracy: 0.9827
# Epoch 94/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9799 - val_loss: 0.1945 - val_accuracy: 0.9705
# Epoch 95/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9828 - val_loss: 0.1945 - val_accuracy: 0.9750
# Epoch 96/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9806 - val_loss: 0.1945 - val_accuracy: 0.9786
# Epoch 97/500
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1947 - accuracy: 0.9828 - val_loss: 0.1946 - val_accuracy: 0.9830
# Epoch 98/500
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1947 - accuracy: 0.9832 - val_loss: 0.1946 - val_accuracy: 0.9860
# Epoch 99/500
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1948 - accuracy: 0.9804 - val_loss: 0.1945 - val_accuracy: 0.9744
# Epoch 100/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1949 - val_accuracy: 0.9761
# Epoch 101/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1948 - val_accuracy: 0.9822
# Epoch 102/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9799 - val_loss: 0.1946 - val_accuracy: 0.9890
# Epoch 103/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9828 - val_loss: 0.1946 - val_accuracy: 0.9847
# Epoch 104/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1947 - val_accuracy: 0.9841
# Epoch 105/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9790 - val_loss: 0.1945 - val_accuracy: 0.9821
# Epoch 106/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1945 - val_accuracy: 0.9722
# Epoch 107/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9826 - val_loss: 0.1945 - val_accuracy: 0.9795
# Epoch 108/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1947 - val_accuracy: 0.9810
# Epoch 109/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9831 - val_loss: 0.1948 - val_accuracy: 0.9853
# Epoch 110/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1949 - accuracy: 0.9808 - val_loss: 0.1950 - val_accuracy: 0.9786
# Epoch 111/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9805 - val_loss: 0.1948 - val_accuracy: 0.9684
# Epoch 112/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9822 - val_loss: 0.1947 - val_accuracy: 0.9803
# Epoch 113/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1947 - val_accuracy: 0.9856
# Epoch 114/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1947 - val_accuracy: 0.9867
# Epoch 115/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1951 - val_accuracy: 0.9785
# Epoch 116/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1949 - val_accuracy: 0.9802
# Epoch 117/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1948 - accuracy: 0.9779 - val_loss: 0.1946 - val_accuracy: 0.9807
# Epoch 118/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1947 - val_accuracy: 0.9718
# Epoch 119/500
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1948 - accuracy: 0.9808 - val_loss: 0.1943 - val_accuracy: 0.9590
# Epoch 120/500
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1950 - accuracy: 0.9774 - val_loss: 0.1948 - val_accuracy: 0.9807
# Epoch 121/500
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1948 - accuracy: 0.9812 - val_loss: 0.1948 - val_accuracy: 0.9871
# Epoch 122/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9818 - val_loss: 0.1947 - val_accuracy: 0.9746
# Epoch 123/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1949 - val_accuracy: 0.9806
# Epoch 124/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9816 - val_loss: 0.1948 - val_accuracy: 0.9820
# Epoch 125/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9795 - val_loss: 0.1946 - val_accuracy: 0.9845
# Epoch 126/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9837 - val_loss: 0.1944 - val_accuracy: 0.9804
# Epoch 127/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9799 - val_loss: 0.1949 - val_accuracy: 0.9711
# Epoch 128/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9818 - val_loss: 0.1948 - val_accuracy: 0.9871
# Epoch 129/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9831 - val_loss: 0.1950 - val_accuracy: 0.9830
# Epoch 130/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9837 - val_loss: 0.1946 - val_accuracy: 0.9836
# Epoch 131/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1945 - val_accuracy: 0.9722
# Epoch 132/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1948 - val_accuracy: 0.9748
# Epoch 133/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1946 - val_accuracy: 0.9852
# Epoch 134/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1946 - val_accuracy: 0.9870
# Epoch 135/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9816 - val_loss: 0.1946 - val_accuracy: 0.9804
# Epoch 136/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1943 - val_accuracy: 0.9747
# Epoch 137/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9803 - val_loss: 0.1951 - val_accuracy: 0.9785
# Epoch 138/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1955 - accuracy: 0.9734 - val_loss: 0.1944 - val_accuracy: 0.9754
# Epoch 139/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1950 - accuracy: 0.9766 - val_loss: 0.1944 - val_accuracy: 0.9636
# Epoch 140/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1942 - val_accuracy: 0.9691
# Epoch 141/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9806 - val_loss: 0.1942 - val_accuracy: 0.9793
# Epoch 142/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1942 - val_accuracy: 0.9662
# Epoch 143/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1946 - val_accuracy: 0.9775
# Epoch 144/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1945 - val_accuracy: 0.9765
# Epoch 145/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1946 - val_accuracy: 0.9774
# Epoch 146/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1945 - val_accuracy: 0.9838
# Epoch 147/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1945 - val_accuracy: 0.9834
# Epoch 148/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9807 - val_loss: 0.1947 - val_accuracy: 0.9776
# Epoch 149/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9798 - val_loss: 0.1946 - val_accuracy: 0.9836
# Epoch 150/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9821 - val_loss: 0.1945 - val_accuracy: 0.9868
# Epoch 151/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1949 - val_accuracy: 0.9643
# Epoch 152/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1947 - val_accuracy: 0.9793
# Epoch 153/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9801 - val_loss: 0.1951 - val_accuracy: 0.9665
# Epoch 154/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1946 - val_accuracy: 0.9854
# Epoch 155/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1945 - val_accuracy: 0.9887
# Epoch 156/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1952 - val_accuracy: 0.9863
# Epoch 157/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9799 - val_loss: 0.1943 - val_accuracy: 0.9680
# Epoch 158/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9815 - val_loss: 0.1943 - val_accuracy: 0.9867
# Epoch 159/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1943 - val_accuracy: 0.9729
# Epoch 160/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9823 - val_loss: 0.1945 - val_accuracy: 0.9804
# Epoch 161/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9812 - val_loss: 0.1947 - val_accuracy: 0.9648
# Epoch 162/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9798 - val_loss: 0.1947 - val_accuracy: 0.9779
# Epoch 163/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1952 - accuracy: 0.9738 - val_loss: 0.1944 - val_accuracy: 0.9794
# Epoch 164/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9811 - val_loss: 0.1944 - val_accuracy: 0.9836
# Epoch 165/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9808 - val_loss: 0.1943 - val_accuracy: 0.9818
# Epoch 166/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9805 - val_loss: 0.1943 - val_accuracy: 0.9853
# Epoch 167/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1945 - val_accuracy: 0.9826
# Epoch 168/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9812 - val_loss: 0.1945 - val_accuracy: 0.9769
# Epoch 169/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1944 - val_accuracy: 0.9866
# Epoch 170/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1943 - val_accuracy: 0.9839
# Epoch 171/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1944 - val_accuracy: 0.9787
# Epoch 172/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9832 - val_loss: 0.1944 - val_accuracy: 0.9859
# Epoch 173/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1945 - val_accuracy: 0.9831
# Epoch 174/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9832 - val_loss: 0.1941 - val_accuracy: 0.9867
# Epoch 175/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1945 - val_accuracy: 0.9825
# Epoch 176/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1943 - val_accuracy: 0.9875
# Epoch 177/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1953 - val_accuracy: 0.9883
# Epoch 178/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1951 - val_accuracy: 0.9831
# Epoch 179/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1951 - val_accuracy: 0.9845
# Epoch 180/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1952 - val_accuracy: 0.9838
# Epoch 181/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1953 - val_accuracy: 0.9835
# Epoch 182/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9853 - val_loss: 0.1952 - val_accuracy: 0.9846
# Epoch 183/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9835 - val_loss: 0.1953 - val_accuracy: 0.9783
# Epoch 184/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9825 - val_loss: 0.1952 - val_accuracy: 0.9816
# Epoch 185/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1951 - val_accuracy: 0.9823
# Epoch 186/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1951 - val_accuracy: 0.9856
# Epoch 187/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1948 - accuracy: 0.9805 - val_loss: 0.1953 - val_accuracy: 0.9775
# Epoch 188/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9821 - val_loss: 0.1947 - val_accuracy: 0.9740
# Epoch 189/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1947 - val_accuracy: 0.9854
# Epoch 190/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9811 - val_loss: 0.1951 - val_accuracy: 0.9853
# Epoch 191/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9836 - val_loss: 0.1942 - val_accuracy: 0.9740
# Epoch 192/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1943 - val_accuracy: 0.9851
# Epoch 193/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1948 - val_accuracy: 0.9858
# Epoch 194/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1941 - val_accuracy: 0.9770
# Epoch 195/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9758 - val_loss: 0.1946 - val_accuracy: 0.9844
# Epoch 196/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9807 - val_loss: 0.1946 - val_accuracy: 0.9800
# Epoch 197/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9834 - val_loss: 0.1946 - val_accuracy: 0.9890
# Epoch 198/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1948 - val_accuracy: 0.9778
# Epoch 199/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9861 - val_loss: 0.1947 - val_accuracy: 0.9859
# Epoch 200/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9854 - val_loss: 0.1945 - val_accuracy: 0.9889
# Epoch 201/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1947 - val_accuracy: 0.9820
# Epoch 202/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9849 - val_loss: 0.1948 - val_accuracy: 0.9821
# Epoch 203/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1948 - val_accuracy: 0.9854
# Epoch 204/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1947 - val_accuracy: 0.9811
# Epoch 205/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1943 - val_accuracy: 0.9792
# Epoch 206/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9811 - val_loss: 0.1945 - val_accuracy: 0.9808
# Epoch 207/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1950 - accuracy: 0.9777 - val_loss: 0.1950 - val_accuracy: 0.9685
# Epoch 208/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9772 - val_loss: 0.1952 - val_accuracy: 0.9759
# Epoch 209/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9796 - val_loss: 0.1951 - val_accuracy: 0.9733
# Epoch 210/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9794 - val_loss: 0.1950 - val_accuracy: 0.9781
# Epoch 211/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9821 - val_loss: 0.1949 - val_accuracy: 0.9808
# Epoch 212/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1949 - val_accuracy: 0.9840
# Epoch 213/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1949 - val_accuracy: 0.9822
# Epoch 214/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1952 - val_accuracy: 0.9804
# Epoch 215/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1949 - val_accuracy: 0.9834
# Epoch 216/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9804 - val_loss: 0.1951 - val_accuracy: 0.9836
# Epoch 217/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9819 - val_loss: 0.1952 - val_accuracy: 0.9859
# Epoch 218/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1952 - val_accuracy: 0.9825
# Epoch 219/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1951 - val_accuracy: 0.9844
# Epoch 220/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1952 - val_accuracy: 0.9864
# Epoch 221/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1952 - val_accuracy: 0.9841
# Epoch 222/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9849 - val_loss: 0.1956 - val_accuracy: 0.9818
# Epoch 223/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9854 - val_loss: 0.1956 - val_accuracy: 0.9754
# Epoch 224/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1953 - val_accuracy: 0.9843
# Epoch 225/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1952 - val_accuracy: 0.9817
# Epoch 226/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9851 - val_loss: 0.1952 - val_accuracy: 0.9822
# Epoch 227/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1952 - val_accuracy: 0.9799
# Epoch 228/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9808 - val_loss: 0.1952 - val_accuracy: 0.9774
# Epoch 229/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1951 - val_accuracy: 0.9832
# Epoch 230/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9851 - val_loss: 0.1956 - val_accuracy: 0.9801
# Epoch 231/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1959 - val_accuracy: 0.9855
# Epoch 232/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9840 - val_loss: 0.1954 - val_accuracy: 0.9770
# Epoch 233/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9796 - val_loss: 0.1954 - val_accuracy: 0.9738
# Epoch 234/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9813 - val_loss: 0.1952 - val_accuracy: 0.9854
# Epoch 235/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1952 - val_accuracy: 0.9832
# Epoch 236/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1951 - val_accuracy: 0.9841
# Epoch 237/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9864 - val_loss: 0.1951 - val_accuracy: 0.9838
# Epoch 238/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9788 - val_loss: 0.1950 - val_accuracy: 0.9831
# Epoch 239/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1950 - val_accuracy: 0.9792
# Epoch 240/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1953 - val_accuracy: 0.9812
# Epoch 241/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1948 - val_accuracy: 0.9879
# Epoch 242/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9829 - val_loss: 0.1957 - val_accuracy: 0.9797
# Epoch 243/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9840 - val_loss: 0.1950 - val_accuracy: 0.9852
# Epoch 244/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1956 - val_accuracy: 0.9839
# Epoch 245/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1954 - val_accuracy: 0.9747
# Epoch 246/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9850 - val_loss: 0.1956 - val_accuracy: 0.9813
# Epoch 247/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9834 - val_loss: 0.1952 - val_accuracy: 0.9835
# Epoch 248/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1954 - val_accuracy: 0.9840
# Epoch 249/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9852 - val_loss: 0.1955 - val_accuracy: 0.9839
# Epoch 250/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9861 - val_loss: 0.1958 - val_accuracy: 0.9882
# Epoch 251/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9850 - val_loss: 0.1958 - val_accuracy: 0.9776
# Epoch 252/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1955 - val_accuracy: 0.9842
# Epoch 253/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1957 - val_accuracy: 0.9800
# Epoch 254/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1955 - val_accuracy: 0.9866
# Epoch 255/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1955 - val_accuracy: 0.9815
# Epoch 256/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1957 - val_accuracy: 0.9719
# Epoch 257/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1953 - val_accuracy: 0.9887
# Epoch 258/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1953 - val_accuracy: 0.9817
# Epoch 259/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1951 - val_accuracy: 0.9886
# Epoch 260/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9840 - val_loss: 0.1949 - val_accuracy: 0.9831
# Epoch 261/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1951 - val_accuracy: 0.9847
# Epoch 262/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1950 - val_accuracy: 0.9868
# Epoch 263/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1947 - val_accuracy: 0.9875
# Epoch 264/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9852 - val_loss: 0.1949 - val_accuracy: 0.9834
# Epoch 265/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1951 - val_accuracy: 0.9862
# Epoch 266/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9849 - val_loss: 0.1950 - val_accuracy: 0.9849
# Epoch 267/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9791 - val_loss: 0.1950 - val_accuracy: 0.9785
# Epoch 268/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1950 - accuracy: 0.9794 - val_loss: 0.1946 - val_accuracy: 0.9717
# Epoch 269/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9816 - val_loss: 0.1957 - val_accuracy: 0.9856
# Epoch 270/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1951 - accuracy: 0.9766 - val_loss: 0.1945 - val_accuracy: 0.9537
# Epoch 271/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9781 - val_loss: 0.1946 - val_accuracy: 0.9833
# Epoch 272/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9824 - val_loss: 0.1946 - val_accuracy: 0.9851
# Epoch 273/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9806 - val_loss: 0.1945 - val_accuracy: 0.9845
# Epoch 274/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1945 - val_accuracy: 0.9866
# Epoch 275/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1945 - val_accuracy: 0.9812
# Epoch 276/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1945 - val_accuracy: 0.9814
# Epoch 277/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9834 - val_loss: 0.1945 - val_accuracy: 0.9863
# Epoch 278/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9838 - val_loss: 0.1945 - val_accuracy: 0.9845
# Epoch 279/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1945 - val_accuracy: 0.9845
# Epoch 280/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9851 - val_loss: 0.1945 - val_accuracy: 0.9827
# Epoch 281/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1945 - val_accuracy: 0.9900
# Epoch 282/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1946 - val_accuracy: 0.9877
# Epoch 283/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9858 - val_loss: 0.1946 - val_accuracy: 0.9898
# Epoch 284/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9852 - val_loss: 0.1946 - val_accuracy: 0.9819
# Epoch 285/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1945 - val_accuracy: 0.9869
# Epoch 286/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9851 - val_loss: 0.1945 - val_accuracy: 0.9856
# Epoch 287/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9861 - val_loss: 0.1946 - val_accuracy: 0.9860
# Epoch 288/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9847 - val_loss: 0.1948 - val_accuracy: 0.9819
# Epoch 289/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9846 - val_loss: 0.1945 - val_accuracy: 0.9831
# Epoch 290/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1945 - val_accuracy: 0.9867
# Epoch 291/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9809 - val_loss: 0.1948 - val_accuracy: 0.9747
# Epoch 292/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1946 - val_accuracy: 0.9784
# Epoch 293/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1944 - val_accuracy: 0.9807
# Epoch 294/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9843 - val_loss: 0.1943 - val_accuracy: 0.9815
# Epoch 295/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9862 - val_loss: 0.1944 - val_accuracy: 0.9759
# Epoch 296/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9850 - val_loss: 0.1944 - val_accuracy: 0.9911
# Epoch 297/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9858 - val_loss: 0.1947 - val_accuracy: 0.9880
# Epoch 298/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9834 - val_loss: 0.1947 - val_accuracy: 0.9656
# Epoch 299/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9856 - val_loss: 0.1947 - val_accuracy: 0.9739
# Epoch 300/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9854 - val_loss: 0.1949 - val_accuracy: 0.9906
# Epoch 301/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9858 - val_loss: 0.1949 - val_accuracy: 0.9770
# Epoch 302/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9859 - val_loss: 0.1946 - val_accuracy: 0.9830
# Epoch 303/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1949 - accuracy: 0.9818 - val_loss: 0.1942 - val_accuracy: 0.9725
# Epoch 304/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1941 - val_accuracy: 0.9789
# Epoch 305/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1942 - val_accuracy: 0.9761
# Epoch 306/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1941 - val_accuracy: 0.9866
# Epoch 307/500
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1951 - val_accuracy: 0.9829
# Epoch 308/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1948 - val_accuracy: 0.9890
# Epoch 309/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9850 - val_loss: 0.1946 - val_accuracy: 0.9820
# Epoch 310/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1941 - val_accuracy: 0.9847
# Epoch 311/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9866 - val_loss: 0.1947 - val_accuracy: 0.9873
# Epoch 312/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1953 - val_accuracy: 0.9770
# Epoch 313/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1945 - val_accuracy: 0.9762
# Epoch 314/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9861 - val_loss: 0.1945 - val_accuracy: 0.9850
# Epoch 315/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9854 - val_loss: 0.1945 - val_accuracy: 0.9795
# Epoch 316/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9847 - val_loss: 0.1946 - val_accuracy: 0.9847
# Epoch 317/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1944 - val_accuracy: 0.9864
# Epoch 318/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1945 - val_accuracy: 0.9846
# Epoch 319/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9851 - val_loss: 0.1945 - val_accuracy: 0.9849
# Epoch 320/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9847 - val_loss: 0.1947 - val_accuracy: 0.9825
# Epoch 321/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9828 - val_loss: 0.1949 - val_accuracy: 0.9845
# Epoch 322/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9824 - val_loss: 0.1948 - val_accuracy: 0.9869
# Epoch 323/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1949 - val_accuracy: 0.9815
# Epoch 324/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9858 - val_loss: 0.1949 - val_accuracy: 0.9842
# Epoch 325/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1950 - val_accuracy: 0.9879
# Epoch 326/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9841 - val_loss: 0.1952 - val_accuracy: 0.9731
# Epoch 327/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1951 - val_accuracy: 0.9782
# Epoch 328/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1951 - val_accuracy: 0.9883
# Epoch 329/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9846 - val_loss: 0.1950 - val_accuracy: 0.9851
# Epoch 330/500
# ...
# Epoch 392/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9850 - val_loss: 0.1962 - val_accuracy: 0.9783
# Epoch 393/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9820 - val_loss: 0.1968 - val_accuracy: 0.9801
# Epoch 394/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1964 - val_accuracy: 0.9811
# Epoch 395/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9830 - val_loss: 0.1963 - val_accuracy: 0.9848
# Epoch 396/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9844 - val_loss: 0.1962 - val_accuracy: 0.9859
# Epoch 397/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9843 - val_loss: 0.1960 - val_accuracy: 0.9786
# Epoch 398/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1962 - val_accuracy: 0.9784
# Epoch 399/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1946 - accuracy: 0.9830 - val_loss: 0.1959 - val_accuracy: 0.9812
# Epoch 400/500
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1947 - accuracy: 0.9850 - val_loss: 0.1957 - val_accuracy: 0.9724
# Epoch 401/500
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1948 - accuracy: 0.9808 - val_loss: 0.1952 - val_accuracy: 0.9773
# Epoch 402/500
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1951 - val_accuracy: 0.9810
# Epoch 403/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1953 - val_accuracy: 0.9807
# Epoch 404/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9823 - val_loss: 0.1964 - val_accuracy: 0.9818
# Epoch 405/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9833 - val_loss: 0.1961 - val_accuracy: 0.9766
# Epoch 406/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1959 - val_accuracy: 0.9743
# Epoch 407/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1958 - val_accuracy: 0.9763
# Epoch 408/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9843 - val_loss: 0.1955 - val_accuracy: 0.9712
# Epoch 409/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9824 - val_loss: 0.1957 - val_accuracy: 0.9767
# Epoch 410/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1955 - val_accuracy: 0.9740
# Epoch 411/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9833 - val_loss: 0.1954 - val_accuracy: 0.9812
# Epoch 412/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9872 - val_loss: 0.1967 - val_accuracy: 0.9851
# Epoch 413/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9842 - val_loss: 0.1958 - val_accuracy: 0.9796
# Epoch 414/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9829 - val_loss: 0.1957 - val_accuracy: 0.9850
# Epoch 415/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1956 - val_accuracy: 0.9766
# Epoch 416/500
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1956 - val_accuracy: 0.9886
# Epoch 417/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9823 - val_loss: 0.1957 - val_accuracy: 0.9819
# Epoch 418/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9863 - val_loss: 0.1957 - val_accuracy: 0.9814
# Epoch 419/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1957 - val_accuracy: 0.9674
# Epoch 420/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1957 - val_accuracy: 0.9712
# Epoch 421/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9839 - val_loss: 0.1956 - val_accuracy: 0.9787
# Epoch 422/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1957 - val_accuracy: 0.9788
# Epoch 423/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9854 - val_loss: 0.1955 - val_accuracy: 0.9756
# Epoch 424/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9849 - val_loss: 0.1954 - val_accuracy: 0.9832
# Epoch 425/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9841 - val_loss: 0.1958 - val_accuracy: 0.9826
# Epoch 426/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9857 - val_loss: 0.1960 - val_accuracy: 0.9698
# Epoch 427/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9862 - val_loss: 0.1957 - val_accuracy: 0.9771
# Epoch 428/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9855 - val_loss: 0.1958 - val_accuracy: 0.9768
# Epoch 429/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9857 - val_loss: 0.1962 - val_accuracy: 0.9818
# Epoch 430/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9852 - val_loss: 0.1954 - val_accuracy: 0.9807
# Epoch 431/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9824 - val_loss: 0.1960 - val_accuracy: 0.9788
# Epoch 432/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9844 - val_loss: 0.1962 - val_accuracy: 0.9761
# Epoch 433/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9814 - val_loss: 0.1958 - val_accuracy: 0.9763
# Epoch 434/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9817 - val_loss: 0.1956 - val_accuracy: 0.9784
# Epoch 435/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9814 - val_loss: 0.1956 - val_accuracy: 0.9764
# Epoch 436/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9831 - val_loss: 0.1954 - val_accuracy: 0.9784
# Epoch 437/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9814 - val_loss: 0.1955 - val_accuracy: 0.9561
# Epoch 438/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9833 - val_loss: 0.1953 - val_accuracy: 0.9790
# Epoch 439/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9828 - val_loss: 0.1944 - val_accuracy: 0.9765
# Epoch 440/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1944 - val_accuracy: 0.9825
# Epoch 441/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9842 - val_loss: 0.1944 - val_accuracy: 0.9855
# Epoch 442/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9859 - val_loss: 0.1943 - val_accuracy: 0.9826
# Epoch 443/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9846 - val_loss: 0.1944 - val_accuracy: 0.9863
# Epoch 444/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9853 - val_loss: 0.1946 - val_accuracy: 0.9780
# Epoch 445/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9822 - val_loss: 0.1945 - val_accuracy: 0.9799
# Epoch 446/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9849 - val_loss: 0.1943 - val_accuracy: 0.9836
# Epoch 447/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9852 - val_loss: 0.1945 - val_accuracy: 0.9833
# Epoch 448/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9852 - val_loss: 0.1945 - val_accuracy: 0.9811
# Epoch 449/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9859 - val_loss: 0.1945 - val_accuracy: 0.9865
# Epoch 450/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9866 - val_loss: 0.1946 - val_accuracy: 0.9804
# Epoch 451/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9867 - val_loss: 0.1948 - val_accuracy: 0.9818
# Epoch 452/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9851 - val_loss: 0.1949 - val_accuracy: 0.9820
# Epoch 453/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9858 - val_loss: 0.1946 - val_accuracy: 0.9819
# Epoch 454/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1951 - accuracy: 0.9738 - val_loss: 0.1954 - val_accuracy: 0.9653
# Epoch 455/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1948 - accuracy: 0.9799 - val_loss: 0.1949 - val_accuracy: 0.9824
# Epoch 456/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1947 - accuracy: 0.9827 - val_loss: 0.1951 - val_accuracy: 0.9794
# Epoch 457/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1948 - val_accuracy: 0.9793
# Epoch 458/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1950 - val_accuracy: 0.9820
# Epoch 459/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1951 - val_accuracy: 0.9789
# Epoch 460/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9844 - val_loss: 0.1952 - val_accuracy: 0.9823
# Epoch 461/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1952 - val_accuracy: 0.9771
# Epoch 462/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9841 - val_loss: 0.1949 - val_accuracy: 0.9791
# Epoch 463/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9856 - val_loss: 0.1948 - val_accuracy: 0.9849
# Epoch 464/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9839 - val_loss: 0.1949 - val_accuracy: 0.9764
# Epoch 465/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1948 - val_accuracy: 0.9808
# Epoch 466/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9866 - val_loss: 0.1948 - val_accuracy: 0.9848
# Epoch 467/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9844 - val_loss: 0.1950 - val_accuracy: 0.9775
# Epoch 468/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9858 - val_loss: 0.1944 - val_accuracy: 0.9757
# Epoch 469/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1948 - accuracy: 0.9815 - val_loss: 0.1947 - val_accuracy: 0.9799
# Epoch 470/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9842 - val_loss: 0.1948 - val_accuracy: 0.9807
# Epoch 471/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1949 - val_accuracy: 0.9786
# Epoch 472/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9853 - val_loss: 0.1953 - val_accuracy: 0.9855
# Epoch 473/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9853 - val_loss: 0.1950 - val_accuracy: 0.9793
# Epoch 474/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9862 - val_loss: 0.1954 - val_accuracy: 0.9822
# Epoch 475/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9869 - val_loss: 0.1952 - val_accuracy: 0.9784
# Epoch 476/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9861 - val_loss: 0.1952 - val_accuracy: 0.9760
# Epoch 477/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9877 - val_loss: 0.1950 - val_accuracy: 0.9808
# Epoch 478/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9857 - val_loss: 0.1952 - val_accuracy: 0.9844
# Epoch 479/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9852 - val_loss: 0.1951 - val_accuracy: 0.9854
# Epoch 480/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9840 - val_loss: 0.1949 - val_accuracy: 0.9790
# Epoch 481/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9850 - val_loss: 0.1947 - val_accuracy: 0.9787
# Epoch 482/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9854 - val_loss: 0.1954 - val_accuracy: 0.9784
# Epoch 483/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9848 - val_loss: 0.1955 - val_accuracy: 0.9803
# Epoch 484/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9842 - val_loss: 0.1954 - val_accuracy: 0.9832
# Epoch 485/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9859 - val_loss: 0.1953 - val_accuracy: 0.9861
# Epoch 486/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9870 - val_loss: 0.1952 - val_accuracy: 0.9837
# Epoch 487/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9861 - val_loss: 0.1952 - val_accuracy: 0.9805
# Epoch 488/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9869 - val_loss: 0.1951 - val_accuracy: 0.9786
# Epoch 489/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1944 - val_accuracy: 0.9725
# Epoch 490/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9858 - val_loss: 0.1943 - val_accuracy: 0.9847
# Epoch 491/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1946 - accuracy: 0.9861 - val_loss: 0.1943 - val_accuracy: 0.9733
# Epoch 492/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1947 - accuracy: 0.9826 - val_loss: 0.1944 - val_accuracy: 0.9722
# Epoch 493/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1948 - accuracy: 0.9789 - val_loss: 0.1950 - val_accuracy: 0.9722
# Epoch 494/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9838 - val_loss: 0.1948 - val_accuracy: 0.9795
# Epoch 495/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9836 - val_loss: 0.1946 - val_accuracy: 0.9755
# Epoch 496/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9830 - val_loss: 0.1952 - val_accuracy: 0.9812
# Epoch 497/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9837 - val_loss: 0.1968 - val_accuracy: 0.9835
# Epoch 498/500
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1947 - accuracy: 0.9834 - val_loss: 0.1955 - val_accuracy: 0.9709
# Epoch 499/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1947 - accuracy: 0.9825 - val_loss: 0.1953 - val_accuracy: 0.9722
# Epoch 500/500
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1947 - accuracy: 0.9845 - val_loss: 0.1953 - val_accuracy: 0.9750
# Threshold: 3.1879623827899085e-05
# array([[8803,  446],
#        [ 644,  593]])

# %% [markdown]
# Muy buenos resultados. Se mejoran mucho con 500 epoch, aunque tarda bastante en generar las predicciones

# %%
df = pd.read_csv('train_CIDDS.csv')
datos_X = pd.DataFrame(df[['Duration', 'Proto', 'DstPt', 'Bytes', 'Flags', 'Tos', 'Packets_speed', 'Bytes_speed']])
datos_y = pd.DataFrame(df[['class']])
x_train = datos_X
y_train = datos_y

df1 = pd.read_csv("muestra1.csv")
x_test = pd.DataFrame(df1[['Duration', 'Proto', 'DstPt', 'Bytes', 'Flags', 'Tos', 'Packets_speed', 'Bytes_speed']])
y_test = pd.DataFrame(df1[['class']])

min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x_train_scaled = min_max_scaler.fit_transform(x_train.copy())
x_test_scaled = min_max_scaler.transform(x_test.copy())

#funciones necesarias
def find_threshold(model, x_train_scaled):
  reconstructions = model.predict(x_train_scaled)
  # provides losses of individual instances
  reconstruction_errors = tf.keras.losses.msle(reconstructions, x_train_scaled)
  # threshold for anomaly scores
  threshold = np.mean(reconstruction_errors.numpy()) \
      + np.std(reconstruction_errors.numpy())
  return threshold

def get_predictions(model, x_test_scaled, threshold):
  predictions = model.predict(x_test_scaled)
  # provides losses of individual instances
  errors = tf.keras.losses.msle(predictions, x_test_scaled)
  # 1 = anomaly, 0 = normal
  anomaly_mask = pd.Series(errors) > threshold
  preds = anomaly_mask.map(lambda x: 1 if x == True else 0)
  return preds

  
import joblib
autoencoder_model3 = open('autoencoder_model3.pkl','rb')
model = joblib.load(autoencoder_model3)

df = pd.read_csv('muestra1.csv')
#df = df.iloc[10483:10484]
X_test = pd.DataFrame(df[['Duration', 'Proto', 'DstPt', 'Bytes', 'Flags', 'Tos', 'Packets_speed', 'Bytes_speed']])
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x_test_scaled = min_max_scaler.fit_transform(X_test.copy())
x_test_scaled = min_max_scaler.transform(X_test.copy())
Y_test = pd.DataFrame(df[['class']]) 
#result = model1.score(X_test, Y_test)
threshold = find_threshold(model, x_train_scaled)

predictions = model.predict(x_test_scaled)
errors = tf.keras.losses.msle(predictions, x_test_scaled)
anomaly_mask = pd.Series(errors) > threshold
preds = anomaly_mask.map(lambda x: 1 if x == True else 0)

predictions = get_predictions(model, x_test_scaled, threshold)
#predictions = pd.DataFrame(predictions)
#predictions = predictions.rename(columns={0:'class_pred'})
#y_test = y_test.rename(columns={1:'class'})
#y_test["class"] = y_test["class"].astype(str).astype(int)

#accuracy_score(predictions, y_test)

#predictions = get_predictions(model3, x_test_scaled, threshold)
if predictions[0] == 1:
  print("Test traffic flow predicted to be Anomalous")
else:
  print("Test traffic flow predicted to be Normal")
# Out:
# Test traffic flow predicted to be Normal
